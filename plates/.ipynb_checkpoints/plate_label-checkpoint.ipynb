# %%
import os
from IPython.display import Image

directory = "/home/fizzer/Desktop/353_ws/plates/"

for filename in os.listdir(directory):
    if filename.startswith("parking"):
        image = Image(filename)
        display(image)

        print("Old name: ", filename)
        new_name = input("What is the parking number (Format P00, for invalid type No): ")
        os.rename(filename, new_name+".jpg")

    elif filename.startswith("license"): 
        image = Image(filename)
        display(image)
        
        print("Old name: ", filename)
        new_name = input("What is the license number (Format 0000, for invalid type No): ")
        os.rename(filename, new_name+".jpg")
        
    else:
        continue
# Out:
# Old name:  license15.jpg
# What is the license number (Format 0000, for invalid type No): SX49
# Old name:  license35.jpg
# What is the license number (Format 0000, for invalid type No): CI92
# Old name:  parking13.jpg
# What is the parking number (Format P00, for invalid type No): P10
# Old name:  license14.jpg
# What is the license number (Format 0000, for invalid type No): IQ86
# Old name:  license19.jpg
# What is the license number (Format 0000, for invalid type No): QV40
# Old name:  license11.jpg
# What is the license number (Format 0000, for invalid type No): ZE77
# Old name:  license32.jpg
# What is the license number (Format 0000, for invalid type No): XQ39
# Old name:  parking32.jpg
# What is the parking number (Format P00, for invalid type No): No
# Old name:  license25.jpg
# What is the license number (Format 0000, for invalid type No): CX30
# Old name:  parking19.jpg
# What is the parking number (Format P00, for invalid type No): P04
# Old name:  license12.jpg
# What is the license number (Format 0000, for invalid type No): LC81
# Old name:  license2.jpg
# What is the license number (Format 0000, for invalid type No): NB48
# Old name:  parking14.jpg
# What is the parking number (Format P00, for invalid type No): P10
# Old name:  license13.jpg
# What is the license number (Format 0000, for invalid type No): NV83
# Old name:  license26.jpg
# What is the license number (Format 0000, for invalid type No): CU87
# Old name:  license34.jpg
# What is the license number (Format 0000, for invalid type No): YP19
# Old name:  license8.jpg
# What is the license number (Format 0000, for invalid type No): QM60
# Old name:  parking35.jpg
# What is the parking number (Format P00, for invalid type No): P14
# Old name:  parking15.jpg
# What is the parking number (Format P00, for invalid type No): P09
# Old name:  license5.jpg
# What is the license number (Format 0000, for invalid type No): LW21
# Old name:  parking22.jpg
# What is the parking number (Format P00, for invalid type No): P03
# Old name:  parking27.jpg
# What is the parking number (Format P00, for invalid type No): P03
# Old name:  parking1.jpg
# What is the parking number (Format P00, for invalid type No): P11
# Old name:  license22.jpg
# What is the license number (Format 0000, for invalid type No): CU94
# Old name:  parking21.jpg
# What is the parking number (Format P00, for invalid type No): P10
# Old name:  parking3.jpg
# What is the parking number (Format P00, for invalid type No): P06
# Old name:  parking7.jpg
# What is the parking number (Format P00, for invalid type No): P13
# Old name:  parking8.jpg
# What is the parking number (Format P00, for invalid type No): P05
# Old name:  license17.jpg
# What is the license number (Format 0000, for invalid type No): ZF84
# Old name:  parking20.jpg
# What is the parking number (Format P00, for invalid type No): P03
# Old name:  license20.jpg
# What is the license number (Format 0000, for invalid type No): JA05
# Old name:  license10.jpg
# What is the license number (Format 0000, for invalid type No): MS83
# Old name:  parking28.jpg
# What is the parking number (Format P00, for invalid type No): P13
# Old name:  license27.jpg
# What is the license number (Format 0000, for invalid type No): AB51
# Old name:  parking26.jpg
# What is the parking number (Format P00, for invalid type No): P09
# Old name:  parking9.jpg
# What is the parking number (Format P00, for invalid type No): P10
# Old name:  parking0.jpg
# What is the parking number (Format P00, for invalid type No): P08
# Old name:  parking24.jpg
# What is the parking number (Format P00, for invalid type No): P10
# Old name:  license7.jpg
# What is the license number (Format 0000, for invalid type No): AO50
# Old name:  license23.jpg
# What is the license number (Format 0000, for invalid type No): FU69
# Old name:  license16.jpg
# What is the license number (Format 0000, for invalid type No): EH96
# Old name:  parking16.jpg
# What is the parking number (Format P00, for invalid type No): P01
# Old name:  parking12.jpg
# What is the parking number (Format P00, for invalid type No): P01
# Old name:  parking31.jpg
# What is the parking number (Format P00, for invalid type No): P09
# Old name:  license9.jpg
# What is the license number (Format 0000, for invalid type No): QP74
# Old name:  license3.jpg
# What is the license number (Format 0000, for invalid type No): No
# Old name:  license4.jpg
# What is the license number (Format 0000, for invalid type No): WA32
# Old name:  parking33.jpg
# What is the parking number (Format P00, for invalid type No): P09
# Old name:  parking17.jpg
# What is the parking number (Format P00, for invalid type No): P07
# Old name:  license24.jpg
# What is the license number (Format 0000, for invalid type No): EB27
# Old name:  parking11.jpg
# What is the parking number (Format P00, for invalid type No): P15
# Old name:  parking30.jpg
# What is the parking number (Format P00, for invalid type No): P13
# Old name:  license0.jpg
# What is the license number (Format 0000, for invalid type No): TX92
# Old name:  parking29.jpg
# What is the parking number (Format P00, for invalid type No): P09
# Old name:  parking4.jpg
# What is the parking number (Format P00, for invalid type No): P03
# Old name:  license30.jpg
# What is the license number (Format 0000, for invalid type No): XQ39
# Old name:  parking23.jpg
# What is the parking number (Format P00, for invalid type No): P12
# Old name:  license6.jpg
# What is the license number (Format 0000, for invalid type No): BN48
# Old name:  license33.jpg
# What is the license number (Format 0000, for invalid type No): PJ25
# Old name:  parking25.jpg
# What is the parking number (Format P00, for invalid type No): P09
# Old name:  parking10.jpg
# What is the parking number (Format P00, for invalid type No): P06
# Old name:  license21.jpg
# What is the license number (Format 0000, for invalid type No): HV74
# Old name:  license18.jpg
# What is the license number (Format 0000, for invalid type No): QC61
# Old name:  license28.jpg
# What is the license number (Format 0000, for invalid type No): XQ39
# Old name:  parking18.jpg
# What is the parking number (Format P00, for invalid type No): P09
# Old name:  license1.jpg
# What is the license number (Format 0000, for invalid type No): WC83
# Old name:  parking5.jpg
# What is the parking number (Format P00, for invalid type No): P02
