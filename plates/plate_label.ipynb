# %%
import os
from IPython.display import Image

directory = "/home/fizzer/Desktop/353_ws/plates/"

for filename in os.listdir(directory):
    if filename.startswith("parking"):
        image = Image(filename)
        display(image)

        print("Old name: ", filename)
        new_name = input("What is the parking number (Format P00, for invalid type No): ")
        os.rename(filename, new_name+".jpg")

    elif filename.startswith("license"): 
        image = Image(filename)
        display(image)
        
        print("Old name: ", filename)
        new_name = input("What is the license number (Format 0000, for invalid type No): ")
        os.rename(filename, new_name+".jpg")
        
    else:
        continue
# Out:
# Old name:  license193.jpg
# What is the license number (Format 0000, for invalid type No): KJ93
# Old name:  license189.jpg
# What is the license number (Format 0000, for invalid type No): DO37
# Old name:  license187.jpg
# What is the license number (Format 0000, for invalid type No): VM97
# Old name:  license188.jpg
# What is the license number (Format 0000, for invalid type No): YY81
# Old name:  license195.jpg
# What is the license number (Format 0000, for invalid type No): OV86
# Old name:  license183.jpg
# What is the license number (Format 0000, for invalid type No): FK90
# Old name:  parking185.jpg
# What is the parking number (Format P00, for invalid type No): P06
# Old name:  license181.jpg
